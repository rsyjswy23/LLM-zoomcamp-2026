# %% [markdown]
# Q1:First trace: How many spans does the trace produce?
# Answer: 3 (each one is a separate ReadableSpan entry.)
# Output: {
#     "name": "search",
#     "context": {
#         "trace_id": "0x8fd7e3bb8c221b171850e54c38e374f7",
#         "span_id": "0xa95ac9ea991d2f3c",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x9df6af58ae31c274",
#     "start_time": "2026-07-20T07:00:44.201109Z",
#     "end_time": "2026-07-20T07:00:44.203259Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "query": "How does the agentic loop keep calling the model until it stops?"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "c67fe727-7d05-43e0-aca5-0f2e3af5dc00",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "llm",
#     "context": {
#         "trace_id": "0x8fd7e3bb8c221b171850e54c38e374f7",
#         "span_id": "0x831f462073b720b0",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x9df6af58ae31c274",
#     "start_time": "2026-07-20T07:00:44.203844Z",
#     "end_time": "2026-07-20T07:00:47.139766Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "prompt": "QUESTION: How does the agentic loop keep calling the model until it stops?\n\nCONTEXT:\n01-agentic-rag/lessons/14-agentic-loop.md\n# The Agentic Loop\n\nVideo: [Watch this lesson](https://www.youtube.com/wa",
#         "input_tokens": 7111,
#         "output_tokens": 119,
#         "cost": 0.0011380499999999998
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "c67fe727-7d05-43e0-aca5-0f2e3af5dc00",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "rag",
#     "context": {
#         "trace_id": "0x8fd7e3bb8c221b171850e54c38e374f7",
#         "span_id": "0x9df6af58ae31c274",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-07-20T07:00:44.201029Z",
#     "end_time": "2026-07-20T07:00:47.140575Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "query": "How does the agentic loop keep calling the model until it stops?"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "c67fe727-7d05-43e0-aca5-0f2e3af5dc00",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
#
# Answer: It keeps looping with a `while True` block and checks whether the model returned any `function_call`

# %% [markdown]
# Q2: Capturing metrics as span attributes
# Answer: ~7000
# Output:    "attributes": {
#         "prompt": "QUESTION: How does the agentic loop keep calling the model until it stops?\n\nCONTEXT:\n01-agentic-rag/lessons/14-agentic-loop.md\n# The Agentic Loop\n\nVideo: [Watch this lesson](https://www.youtube.com/wa",
#         "input_tokens": 7111,
#         "output_tokens": 119,
#         "cost": 0.0011380499999999998
#     },

# %% [markdown]
# Q3: Span timing
# Answer: Over 2000 ms.
# Output:  "start_time": "2026-07-20T07:00:44.203844Z",
#     "end_time": "2026-07-20T07:00:47.139766Z",

# %% [markdown]
# Q4: Which span names appear in the spans table?
# Answer: search llm rag
# Output:
# @rsyjswy23 ➜ /workspaces/LLM-zoomcamp-2026/llm-zoomcamp-hw5 (main) $ uv run python traced_rag.py
#
# Answer: The loop keeps calling the model by using a `while True` loop and checking whether the response cont
# @rsyjswy23 ➜ /workspaces/LLM-zoomcamp-2026/llm-zoomcamp-hw5 (main) $ sqlite3 traces.db "SELECT DISTINCT name FROM spans;"
# search
# llm
# rag
# @rsyjswy23 ➜ /workspaces/LLM-zoomcamp-2026/llm-zoomcamp-hw5 (main) $

# %% [markdown]
# Q5: Querying trace data: Which span type takes the most total time?
# Answer: llm
# Output: (code in q5-sql.py)
# (llm-zoomcamp-2026) @rsyjswy23 ➜ /workspaces/LLM-zoomcamp-2026/llm-zoomcamp-hw5 (main) $ python q5-sql.py
# name
# llm       2820.532187
# search       1.836235
# Name: duration_ms, dtype: float64

# %% [markdown]
# Q6: Token stability across runs
# Answer: they are identical.
# Output: (code in q6-sql.py)
# (llm-zoomcamp-2026) @rsyjswy23 ➜ /workspaces/LLM-zoomcamp-2026/llm-zoomcamp-hw5 (main) $ python q6-sql.py
# count       4.0
# mean     7111.0
# std         0.0
# min      7111.0
# 25%      7111.0
# 50%      7111.0
# 75%      7111.0
# max      7111.0
# Name: input_tokens, dtype: float64
# Std dev: 0.00
# Mean: 7111.00
# CV: 0.00%
